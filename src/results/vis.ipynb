# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data=np.load('stochastic/ql_tr_online_no.npy')

# %%
n_eps, n_runs = data.shape

# %%
df = pd.DataFrame(data={"Episode": np.tile(np.arange(500),reps=200),
                        "Rewards": data.flatten('F')})

# %%
a = sns.lineplot(x="Episode", y="Rewards", data=df)
# a.set_title("Q-Learning with deterministic environment")
plt.show()
